# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !pip install ultralytics roboflow jupyter

# %%
#!pip install roboflow ultralytics
from roboflow import Roboflow
import os

rf = Roboflow(api_key="xPUpPw3Cakcrlvp5XMMl")
project = rf.workspace("damians-workspace-enpcl").project("garbage-classification-3-goezd")
version = project.version(2)
dataset = version.download("yolo26")

# Check if the path exists
data_path = os.path.join(os.getcwd(), "GARBAGE-CLASSIFICATION-3-2", "data.yaml")
print(f"Data is ready at: {data_path}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Data is ready at: C:\Users\damia\Documents\jupyter_notebooks\projects\GARBAGE-CLASSIFICATION-3-2\data.yaml

# %%
from ultralytics import YOLO

# Load YOLO26 Nano model
model = YOLO('yolo26n.pt')

# dataset folder
my_phase2_data = r'C:\Users\damia\Documents\jupyter_notebooks\projects\GARBAGE-CLASSIFICATION-3-2\data.yaml'

# 3. High-Performance Training
model.train(
    data=my_phase2_data,
    epochs=100,
    imgsz=640,
    batch=-1,
    device=0,
    workers=0,
    name='trash_tracker_PHASE2_AUGMENTED',
    overlap_mask=True,  # Crucial for merging overlapping tomato boxes
    close_mosaic=10     # Turns off mosaic for the last 10 epochs for precision
)
# Out:
# Ultralytics 8.4.37  Python-3.10.19 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 16303MiB)
# ...

# %%
from ultralytics import YOLO

# 1. Load the NEW weights from Phase 2
phase2_model_path = r"C:\Users\damia\Documents\jupyter_notebooks\projects\runs\detect\trash_tracker_PHASE2_AUGMENTED3\weights\best.pt"
model = YOLO(phase2_model_path)

# 2. Validate on the Version 2 Dataset
# This will automatically use the /2/valid folder defined in your yaml
metrics = model.val()

# 3. Print the Class-Specific Breakdown (This is the most important part!)
print("Class-specific mAP50:")
for name, mAP in zip(metrics.names.values(), metrics.box.maps):
    print(f"{name}: {mAP:.4f}")

print(f"\nOverall mAP50: {metrics.box.map50:.4f}")
# Out:
# Ultralytics 8.4.37  Python-3.10.19 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5080, 16303MiB)
# YOLO26n summary (fused): 122 layers, 2,376,006 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 507.7452.0 MB/s, size: 46.0 KB)
# val: Scanning C:\Users\damia\Documents\jupyter_notebooks\projects\GARBAGE-CLASSIFICATION-3-2\valid\labels.cache... 2093 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2093/2093  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 131/131 12.9it/s 10.2s0.1s
#                    all       2093      18889      0.626      0.568        0.6      0.425
#          BIODEGRADABLE        674      13618      0.733      0.588       0.66      0.386
#              CARDBOARD        437       1288      0.729      0.576      0.644      0.495
#                  GLASS        803       2376      0.863      0.774      0.851       0.66
# ...
